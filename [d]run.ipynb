# %%
from ultralytics import YOLO

model = YOLO("yolo26m.pt")

video_path = "./data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm"

for result in model.predict(
    source=video_path,
    save=True,
    stream=True,
):
    pass
# Out:
# ...
#
# video 1/1 (frame 1/750) /Users/adi/Skaarfacee/github/PitchSense_keypoint/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 384x640 19 persons, 1 sports ball, 159.3ms
# video 1/1 (frame 2/750) /Users/adi/Skaarfacee/github/PitchSense_keypoint/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 384x640 20 persons, 1 sports ball, 121.7ms
# video 1/1 (frame 3/750) /Users/adi/Skaarfacee/github/PitchSense_keypoint/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 384x640 18 persons, 1 sports ball, 176.6ms
# video 1/1 (frame 4/750) /Users/adi/Skaarfacee/github/PitchSense_keypoint/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 384x640 19 persons, 1 sports ball, 159.6ms
# ...

# %%
# Out:
#   Cell In[1], line 2
#     "./data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm"
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from ultralytics import YOLO
import cv2

img_path = "/Users/adi/Skaarfacee/github/PitchSense/data/train/00996.jpg"

# Load image
img = cv2.imread(img_path)

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert grayscale back to 3 channels
gray_3ch = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

# Run YOLO prediction on grayscale image
results = model.predict(
    source=gray_3ch,
    save=True,
)
# Out:
# 0: 736x1280 6 players, 519.6ms
# Speed: 34.9ms preprocess, 519.6ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to /Users/adi/Skaarfacee/github/PitchSense/runs/detect/predict2
